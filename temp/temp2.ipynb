# %%
import matplotlib.pyplot as plt

# %%
force = [42.1,84.2,126.3,168.3,210.1,251.5,292.2,332.2,371.2,409.1,445.7,480.9,514.7,546.9,577.6,606.7,634.5,660.7,685.6,709.1,731.4,752.4,772.3,791.1,808.8,825.6,841.5,856.5,870.7,884.1,896.8,908.6,919.7,930.0,939.7,948.7,956.9,964.5,971.3,977.3,982.5,986.8,990.5,993.6,996.2,998.5,1000.6,1002.4,1004.0,1005.6]
displacement = [0.1*(i+1) for i in range(len(force))]
plt.plot(displacement, force)

force = [42.1,84.2,126.3,168.3,210.1]
plt.scatter(0.1*len(force), force[-1], color = 'red')
